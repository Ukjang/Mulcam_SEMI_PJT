# %%
import pandas as pd
import numpy as np
from glob import glob
from tqdm import tqdm

# %%
pwd
# Out:
# 'C:\\Users\\Admin\\Desktop\\multi\\기상관측 데이터\\data'

# %%
cd data
# Out:
# C:\Users\Admin\Desktop\multi\기상관측 데이터\data

# %%
file_list
# Out:
# ['C:/Users/Admin/Desktop/multi/기상관측 데이터/data']

# %%
file_list = glob('*.xlsx')
file_list
# Out:
# ['kma20220504152456565.xlsx',
#  'kma20220504152517563.xlsx',
#  'kma20220504152539162.xlsx',
#  'kma20220504152559849.xlsx',
#  'kma20220504152620848.xlsx',
#  'kma20220504152642216.xlsx',
#  'kma20220504152703397.xlsx',
#  'kma20220504152724066.xlsx',
#  'kma20220504152744705.xlsx',
#  'kma20220504152806032.xlsx',
#  'kma20220504152826708.xlsx',
#  'kma20220504152847983.xlsx',
#  'kma20220504152908654.xlsx',
#  'kma20220504152929835.xlsx',
#  'kma20220504152951443.xlsx',
#  'kma20220504153012169.xlsx',
#  'kma20220504153033263.xlsx',
#  'kma20220504153054613.xlsx',
#  'kma20220504153115209.xlsx',
#  'kma20220504153136107.xlsx',
#  'kma20220504153157003.xlsx',
#  'kma20220504153217999.xlsx',
#  'kma20220504153239335.xlsx',
#  'kma20220504153300751.xlsx',
#  'kma20220504153321414.xlsx',
#  'kma20220504153342662.xlsx',
#  'kma20220504153403731.xlsx',
#  'kma20220504153424755.xlsx',
#  'kma20220504153444806.xlsx',
#  'kma20220504153506158.xlsx',
#  'kma20220504153526965.xlsx',
# ...

# %%
df = pd.read_excel(file_list[0])
df.head()
# Out:
# C:\Users\Admin\anaconda3\envs\kdig\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#        거래일자 지역(시) 지역(군)  평균기온  최고기온  최저기온  강수량  일조시간  일사량    습도   운량  적설량  \
# 0  19880101    서울   종로구  -2.4  -0.8  -4.4  0.5   0.0  1.0  64.0  0.0  0.0
# 1  19880101    서울   관악구  -2.6   0.5  -6.2  1.9   0.0  0.0  73.0  0.0  0.0
# 2  19880101   강원도   춘천시  -4.1  -0.7  -8.6  0.0   0.0  1.0  66.0  0.0  0.0
# 3  19880101   강원도   철원군  -3.1  -1.0  -8.6  0.4   0.0  1.0  79.0  0.0  0.0
# 4  19880101   강원도   속초시   3.7   6.5   0.1  0.0   0.0  0.0  57.0  0.0  0.0
#
#    순간최대풍속 조사지역
# 0     0.0   서울
# 1     0.0  관악산
# 2     0.0   춘천
# 3     0.0   철원
# 4     0.0   속초

# %%
df1 = pd.DataFrame()
for file in tqdm(file_list) :
    df2 = pd.read_excel(file)
    df1 = pd.concat([df1, df2])
df1.info()
# Out:
#   3%|██▎                                                                                | 1/35 [00:11<06:44, 11.90s/it]C:\Users\Admin\anaconda3\envs\kdig\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#   6%|████▋                                                                              | 2/35 [00:23<06:35, 11.99s/it]C:\Users\Admin\anaconda3\envs\kdig\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#   9%|███████                                                                            | 3/35 [00:36<06:24, 12.02s/it]C:\Users\Admin\anaconda3\envs\kdig\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
# ...

# %%
display(df1.head(10))
df1.tail(10)
# Out:
#        거래일자 지역(시) 지역(군)  평균기온  최고기온  최저기온  강수량  일조시간  일사량    습도   운량  적설량  \
# 0  19880101    서울   종로구  -2.4  -0.8  -4.4  0.5   0.0  1.0  64.0  0.0  0.0
# 1  19880101    서울   관악구  -2.6   0.5  -6.2  1.9   0.0  0.0  73.0  0.0  0.0
# 2  19880101   강원도   춘천시  -4.1  -0.7  -8.6  0.0   0.0  1.0  66.0  0.0  0.0
# 3  19880101   강원도   철원군  -3.1  -1.0  -8.6  0.4   0.0  1.0  79.0  0.0  0.0
# 4  19880101   강원도   속초시   3.7   6.5   0.1  0.0   0.0  0.0  57.0  0.0  0.0
# 5  19880101   강원도   원주시  -5.1  -1.5  -9.8  0.0   0.0  2.0  65.0  0.0  0.0
# 6  19880101   강원도   평창군  -4.4  -0.6  -8.8  0.0   0.0  3.0  63.0  0.0  0.0
# 7  19880101   강원도   태백시  -1.0   2.6  -6.3  0.0   0.0  0.0  61.0  0.0  0.0
# 8  19880101   강원도   삼척시   3.8   6.9  -3.0  0.0   0.0  0.0  62.0  0.0  0.0
# 9  19880101   강원도   인제군  -3.3   0.6  -9.1  0.0   0.0  0.0  70.0  0.0  0.0
#
#    순간최대풍속 조사지역
# 0     0.0   서울
# 1     0.0  관악산
# 2     0.0   춘천
# 3     0.0   철원
# 4     0.0   속초
# 5     0.0   원주
# 6     0.0  대관령
# 7     0.0   태백
# ...

# %%
df1.to_csv('기상데이터 전체.csv')
